# %%
import matplotlib.pyplot as plt
import numpy as np
from misc import *
# from ipynb.fs.full.Formulas import *
# from ipynb.fs.full.Environment import *
# from ipynb.fs.full.Flow_Grouping_Algo import *

# %%
plt.plot(x_cords_fig1,y_cords_1_fig1, color='blue', label='RCS',marker = '*')
plt.plot(x_cords_fig1,y_cords_2_fig1, color='red', label='JRDS',marker = 'p')
plt.xlabel('Interference Threshold')
plt.ylabel('Number of Groups')
plt.title('Interference Threshold vs Number of Groups')
plt.xticks(custom_ticks_fig1, custom_labels_fig1)
plt.legend()
plt.show()

# %%
plt.plot(x_cords_fig2,y_cords_rcs_fig2, color='blue', label='RCS',marker = '*')
plt.plot(x_cords_fig2,y_cords_jrds_fig2, color='red', label='JRDS',marker = 'p')
plt.xlabel('Number of Flows')
plt.ylabel('Transmission Time (No of slots consumed)')
plt.title('Number of Flows vs Number of slots consumed')
plt.xticks(x_cords_fig2)
plt.legend()
plt.show()

# %%
plt.plot(x_cords_fig3,y_cords_rcs_fig3, color='blue', label='RCS',marker = '*')
plt.plot(x_cords_fig3,y_cords_jrds_fig3, color='red', label='JRDS',marker = 'p')
plt.xlabel('Interference Threshold')
plt.ylabel('Transmission Time (No of slots consumed)')
plt.title('Interference Threshold vs Number of slots consumed')
plt.xticks(custom_ticks_fig3,custom_labels_fig3)
plt.legend()
plt.show()

# %%
plt.plot(x_cords_fig4,y_cords_rcs_fig4, color='blue', label='RCS',marker = '*')
plt.plot(x_cords_fig4,y_cords_jrds_fig4, color='red', label='JRDS',marker = 'p')
plt.xlabel('Number of Flows')
plt.ylabel('Network Throughput (Gbps)')
plt.title('Number of Flows vs Network Throughput')
plt.xticks(x_cords_fig4)
plt.legend()
plt.savefig('new.png')
plt.show()

# %%
plt.plot(x_cords_fig5,y_cords_rcs_fig5, color='blue', label='RCS',marker = '*')
plt.plot(x_cords_fig5,y_cords_jrds_fig5, color='red', label='JRDS',marker = 'p')
plt.xlabel('Interference Threshold')
plt.ylabel('Network Throughput (Gbps)')
plt.title('Interference Threshold vs Network Throughput')
plt.xticks(custom_ticks_fig5,custom_labels_fig5)
plt.legend()
plt.show()
