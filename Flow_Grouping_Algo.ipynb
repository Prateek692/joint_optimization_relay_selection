# %%
import pandas as pd
import numpy as np
from ipynb.fs.full.Formulas import *
from ipynb.fs.full.Environment import *
# Out:
# Bhaichara On Top

# %% [markdown]
# # Created Graph class where vertice = flow and edge indicates contention between 2 particular flows

# %%
class Graph:
    def __init__(self):
        self.adjacency_list = {}
        self.edge_list = set()

    def add_node(self, node):
        if node not in self.adjacency_list:
            self.adjacency_list[node] = set()

    def add_edge(self, node1, node2):
        self.add_node(node1)
        self.add_node(node2)
        self.adjacency_list[node1].add(node2)
        self.adjacency_list[node2].add(node1)
        self.edge_list.add((node1,node2))
        self.edge_list.add((node2,node1))

    def remove_edge(self, node1, node2):
        if node1 in self.adjacency_list and node2 in self.adjacency_list:
            if node2 in self.adjacency_list[node1]:
                self.adjacency_list[node1].remove(node2)
                self.adjacency_list[node2].remove(node1)
        self.edge_list.remove((node1,node2))
        self.edge_list.remove((node2,node1))

    def get_nodes_by_degree(self):
        nodes_with_degrees = [(node, len(neighbors)) for node, neighbors in self.adjacency_list.items()]
        return [node for node, _ in sorted(nodes_with_degrees, key=lambda x: x[1])]

    def is_edge(self,node1,node2):
        return (node1,node2) in self.edge_list and (node2,node1) in self.edge_list

# %% [markdown]
# ### This function checks whether there is contention happening between 2 flows for concurrent transmissions

# %%
def check_create_edge(flow1,flow2):
    flow1_sender = flow1[2]
    flow1_receiver = flow1[3]
    flow2_sender = flow2[2]
    flow2_receiver = flow2[3]

    if flow1_sender == flow2_sender or flow1_receiver == flow2_receiver: # 2 flows conflicting due to FD mode, therefore contention definitely happens
        return True
    # Contention occurs only if relative interference (RI) between 2 flows exceeds defined threshold value
    elif flow1_sender == flow2_receiver and flow2_sender == flow1_receiver: 
        return calculate_relative_intereference1() > interference_threshold
    elif flow1_sender == flow2_receiver:
        return max(calculate_relative_intereference1(),calculate_relative_intereference2(flow2_sender,flow1_receiver)) > interference_threshold
    elif flow2_sender == flow1_receiver:
        return max(calculate_relative_intereference1(),calculate_relative_intereference2(flow1_sender,flow2_receiver)) > interference_threshold
    else:
        return max(calculate_relative_intereference2(flow1_sender,flow2_receiver),calculate_relative_intereference2(flow2_sender,flow1_receiver)) > interference_threshold

# %% [markdown]
# # Generating dynamic contention graph between flows for each timestamp

# %%
# for current_time_slot in range(number_of_time_slots):
#     time = current_time_slot * slot_duration
def flow_graph_generate():
    # Creating a graph for each time slot
    graph = Graph()
    # Comparing flow pair at a time for graph connection
    for flow1 in flows:
        flow_with_time1 = [flow1[0].calculate_position(0.0), flow1[1].calculate_position(0.0), 0.0]
        flow_with_time1 = str(flow_with_time1)
        if flow_with_time1 not in flows_candidate_relay_set_pairs:
            continue
        relay_type1, candidate_set1, random_candidate1 = flows_candidate_relay_set_pairs[flow_with_time1]
        # If flow 1 is not relayed OR there is no relaying candidate for flow, no need to include it in graph
        if relay_type1 == 'dont_relay' or random_candidate1 == -1:
            continue
        for flow2 in flows:
            if flow1.all() == flow2.all(): # Redundant because 2 flows are same so no need to calculate
                continue
            flow_with_time2 = [flow2[0].calculate_position(0.0), flow2[1].calculate_position(0.0), 0.0]
            flow_with_time2 = str(flow_with_time2)
            if flow_with_time2 not in flows_candidate_relay_set_pairs:
                continue
        
            relay_type2, candidate_set2, random_candidate2 = flows_candidate_relay_set_pairs[flow_with_time2]
            # If flow 2 is not relayed OR there is no relaying candidate for flow, no need to include it in graph
            if relay_type2 == 'dont_relay' or random_candidate2 == -1:
                continue
            # If random relaying candidate coincide for 2 flows OR there is contention between 2 flows, then connect those flows(nodes) via graph edge            if random_candidate1 == random_candidate2 or check_create_edge(flow1,flow2):   
            graph.add_edge(tuple(flow1),tuple(flow2))

    # Now we make groups in graph so that each group contains flows that are not in contention  
    # List of groups of graqh, where elements in a single group aren't in contention with each other
    groups = []
    #List of flows sorted in ascending order of their degree(no of edges)
    degree_sorted_node_list = graph.get_nodes_by_degree()
    for node in degree_sorted_node_list:
        found_group = False
        for group in groups:
            no_edge = True
            for flow in group:
                if graph.is_edge(node,flow): #If the node to be added is having contention with the flow in particular group, then we cant add them together
                    no_edge = False
                    break
            if no_edge == True: #If no contention exists between node and flows of particular group, they can be kept together in same group 
                group.append(node)
                found_group = True
                break
        if found_group == False: # If no suitable group is found for the flow, then create a new group for that flow altogether
            groups.append([node])

    return graph

# %%
Graphs = flow_graph_generate()

# %%
flows_candidate_relay_set_pairs
# Out:
# {'[(10.0, 1), (15.0, 2), 0.0]': ['dont_relay', set(), -1],
#  '[(10.0, 1), (20.0, 3), 0.0]': ['middle_lane_relay', set(), -1],
#  '[(10.0, 1), (25.0, 1), 0.0]': ['dont_relay', set(), -1],
#  '[(10.0, 1), (30.0, 2), 0.0]': ['dont_relay', set(), -1],
#  '[(10.0, 1), (35.0, 3), 0.0]': ['middle_lane_relay', set(), -1],
#  '[(10.0, 1), (40.0, 1), 0.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(10.0, 1), (45.0, 2), 0.0]': ['dont_relay', set(), -1],
#  '[(10.0, 1), (50.0, 3), 0.0]': ['middle_lane_relay', set(), -1],
#  '[(13.0, 1), (18.5, 2), 0.1]': ['dont_relay', set(), -1],
#  '[(13.0, 1), (24.0, 3), 0.1]': ['middle_lane_relay', set(), -1],
#  '[(13.0, 1), (29.5, 1), 0.1]': ['dont_relay', set(), -1],
#  '[(13.0, 1), (35.0, 2), 0.1]': ['dont_relay', set(), -1],
#  '[(13.0, 1), (40.5, 3), 0.1]': ['middle_lane_relay', set(), -1],
#  '[(13.0, 1), (46.0, 1), 0.1]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(13.0, 1), (51.5, 2), 0.1]': ['dont_relay', set(), -1],
#  '[(13.0, 1), (57.0, 3), 0.1]': ['middle_lane_relay', set(), -1],
#  '[(16.0, 1), (22.0, 2), 0.2]': ['dont_relay', set(), -1],
#  '[(16.0, 1), (28.0, 3), 0.2]': ['middle_lane_relay', set(), -1],
#  '[(16.0, 1), (34.0, 1), 0.2]': ['dont_relay', set(), -1],
#  '[(16.0, 1), (40.0, 2), 0.2]': ['dont_relay', set(), -1],
#  '[(16.0, 1), (46.0, 3), 0.2]': ['middle_lane_relay', set(), -1],
#  '[(16.0, 1), (52.0, 1), 0.2]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(16.0, 1), (58.0, 2), 0.2]': ['dont_relay', set(), -1],
#  '[(16.0, 1), (64.0, 3), 0.2]': ['middle_lane_relay', set(), -1],
#  '[(19.0, 1), (25.5, 2), 0.30000000000000004]': ['dont_relay', set(), -1],
#  '[(19.0, 1), (32.0, 3), 0.30000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(19.0, 1), (38.5, 1), 0.30000000000000004]': ['dont_relay', set(), -1],
#  '[(19.0, 1), (45.0, 2), 0.30000000000000004]': ['dont_relay', set(), -1],
#  '[(19.0, 1), (51.5, 3), 0.30000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(19.0, 1), (58.0, 1), 0.30000000000000004]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(19.0, 1), (64.5, 2), 0.30000000000000004]': ['dont_relay', set(), -1],
#  '[(19.0, 1), (71.0, 3), 0.30000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(22.0, 1), (29.0, 2), 0.4]': ['dont_relay', set(), -1],
#  '[(22.0, 1), (36.0, 3), 0.4]': ['middle_lane_relay', set(), -1],
#  '[(22.0, 1), (43.0, 1), 0.4]': ['dont_relay', set(), -1],
#  '[(22.0, 1), (50.0, 2), 0.4]': ['dont_relay', set(), -1],
#  '[(22.0, 1), (57.0, 3), 0.4]': ['middle_lane_relay', set(), -1],
#  '[(22.0, 1), (64.0, 1), 0.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(22.0, 1), (71.0, 2), 0.4]': ['dont_relay', set(), -1],
#  '[(22.0, 1), (78.0, 3), 0.4]': ['middle_lane_relay', set(), -1],
#  '[(25.0, 1), (32.5, 2), 0.5]': ['dont_relay', set(), -1],
#  '[(25.0, 1), (40.0, 3), 0.5]': ['middle_lane_relay', set(), -1],
#  '[(25.0, 1), (47.5, 1), 0.5]': ['dont_relay', set(), -1],
#  '[(25.0, 1), (55.0, 2), 0.5]': ['dont_relay', set(), -1],
#  '[(25.0, 1), (62.5, 3), 0.5]': ['middle_lane_relay', set(), -1],
#  '[(25.0, 1), (70.0, 1), 0.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(25.0, 1), (77.5, 2), 0.5]': ['dont_relay', set(), -1],
#  '[(25.0, 1), (85.0, 3), 0.5]': ['middle_lane_relay', set(), -1],
#  '[(28.000000000000004, 1), (36.0, 2), 0.6000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(28.000000000000004, 1), (44.0, 3), 0.6000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(28.000000000000004, 1), (52.0, 1), 0.6000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(28.000000000000004, 1), (60.0, 2), 0.6000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(28.000000000000004, 1), (68.0, 3), 0.6000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(28.000000000000004, 1), (76.0, 1), 0.6000000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(28.000000000000004, 1), (84.0, 2), 0.6000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(28.000000000000004, 1), (92.0, 3), 0.6000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (39.5, 2), 0.7000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (48.0, 3), 0.7000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (56.5, 1), 0.7000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (65.0, 2), 0.7000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (73.5, 3), 0.7000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (82.0, 1), 0.7000000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(31.000000000000004, 1), (90.5, 2), 0.7000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(31.000000000000004, 1), (99.0, 3), 0.7000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(34.0, 1), (43.0, 2), 0.8]': ['dont_relay', set(), -1],
#  '[(34.0, 1), (52.0, 3), 0.8]': ['middle_lane_relay', set(), -1],
#  '[(34.0, 1), (61.0, 1), 0.8]': ['dont_relay', set(), -1],
#  '[(34.0, 1), (70.0, 2), 0.8]': ['dont_relay', set(), -1],
#  '[(34.0, 1), (79.0, 3), 0.8]': ['middle_lane_relay', set(), -1],
#  '[(34.0, 1), (88.0, 1), 0.8]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(34.0, 1), (97.0, 2), 0.8]': ['dont_relay', set(), -1],
#  '[(34.0, 1), (106.0, 3), 0.8]': ['middle_lane_relay', set(), -1],
#  '[(37.0, 1), (46.5, 2), 0.9]': ['dont_relay', set(), -1],
#  '[(37.0, 1), (56.0, 3), 0.9]': ['middle_lane_relay', set(), -1],
#  '[(37.0, 1), (65.5, 1), 0.9]': ['dont_relay', set(), -1],
#  '[(37.0, 1), (75.0, 2), 0.9]': ['dont_relay', set(), -1],
#  '[(37.0, 1), (84.5, 3), 0.9]': ['middle_lane_relay', set(), -1],
#  '[(37.0, 1), (94.0, 1), 0.9]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(37.0, 1), (103.5, 2), 0.9]': ['dont_relay', set(), -1],
#  '[(37.0, 1), (113.0, 3), 0.9]': ['middle_lane_relay', set(), -1],
#  '[(40.0, 1), (50.0, 2), 1.0]': ['dont_relay', set(), -1],
#  '[(40.0, 1), (60.0, 3), 1.0]': ['middle_lane_relay', set(), -1],
#  '[(40.0, 1), (70.0, 1), 1.0]': ['dont_relay', set(), -1],
#  '[(40.0, 1), (80.0, 2), 1.0]': ['dont_relay', set(), -1],
#  '[(40.0, 1), (90.0, 3), 1.0]': ['middle_lane_relay', set(), -1],
#  '[(40.0, 1), (100.0, 1), 1.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(40.0, 1), (110.0, 2), 1.0]': ['dont_relay', set(), -1],
#  '[(40.0, 1), (120.0, 3), 1.0]': ['middle_lane_relay', set(), -1],
#  '[(43.0, 1), (53.5, 2), 1.1]': ['dont_relay', set(), -1],
#  '[(43.0, 1), (64.0, 3), 1.1]': ['middle_lane_relay', set(), -1],
#  '[(43.0, 1), (74.5, 1), 1.1]': ['dont_relay', set(), -1],
#  '[(43.0, 1), (85.0, 2), 1.1]': ['dont_relay', set(), -1],
#  '[(43.0, 1), (95.5, 3), 1.1]': ['middle_lane_relay', set(), -1],
#  '[(43.0, 1), (106.0, 1), 1.1]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(43.0, 1), (116.5, 2), 1.1]': ['dont_relay', set(), -1],
#  '[(43.0, 1), (127.0, 3), 1.1]': ['middle_lane_relay', set(), -1],
#  '[(46.00000000000001, 1), (57.00000000000001, 2), 1.2000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(46.00000000000001, 1), (68.0, 3), 1.2000000000000002]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(46.00000000000001, 1), (79.0, 1), 1.2000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(46.00000000000001, 1), (90.0, 2), 1.2000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(46.00000000000001, 1), (101.00000000000001, 3), 1.2000000000000002]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(46.00000000000001, 1), (112.00000000000001, 1), 1.2000000000000002]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(46.00000000000001, 1), (123.00000000000001, 2), 1.2000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(46.00000000000001, 1), (134.0, 3), 1.2000000000000002]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(49.0, 1), (60.5, 2), 1.3]': ['dont_relay', set(), -1],
#  '[(49.0, 1), (72.0, 3), 1.3]': ['middle_lane_relay', set(), -1],
#  '[(49.0, 1), (83.5, 1), 1.3]': ['dont_relay', set(), -1],
#  '[(49.0, 1), (95.0, 2), 1.3]': ['dont_relay', set(), -1],
#  '[(49.0, 1), (106.5, 3), 1.3]': ['middle_lane_relay', set(), -1],
#  '[(49.0, 1), (118.0, 1), 1.3]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(49.0, 1), (129.5, 2), 1.3]': ['dont_relay', set(), -1],
#  '[(49.0, 1), (141.0, 3), 1.3]': ['middle_lane_relay', set(), -1],
#  '[(52.00000000000001, 1), (64.0, 2), 1.4000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(52.00000000000001, 1), (76.0, 3), 1.4000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(52.00000000000001, 1), (88.0, 1), 1.4000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(52.00000000000001, 1), (100.0, 2), 1.4000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(52.00000000000001, 1), (112.00000000000001, 3), 1.4000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(52.00000000000001, 1), (124.00000000000001, 1), 1.4000000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(52.00000000000001, 1), (136.0, 2), 1.4000000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(52.00000000000001, 1), (148.0, 3), 1.4000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(55.0, 1), (67.5, 2), 1.5]': ['dont_relay', set(), -1],
#  '[(55.0, 1), (80.0, 3), 1.5]': ['middle_lane_relay', set(), -1],
#  '[(55.0, 1), (92.5, 1), 1.5]': ['dont_relay', set(), -1],
#  '[(55.0, 1), (105.0, 2), 1.5]': ['dont_relay', set(), -1],
#  '[(55.0, 1), (117.5, 3), 1.5]': ['middle_lane_relay', set(), -1],
#  '[(55.0, 1), (130.0, 1), 1.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(55.0, 1), (142.5, 2), 1.5]': ['dont_relay', set(), -1],
#  '[(55.0, 1), (155.0, 3), 1.5]': ['middle_lane_relay', set(), -1],
#  '[(58.0, 1), (71.0, 2), 1.6]': ['dont_relay', set(), -1],
#  '[(58.0, 1), (84.0, 3), 1.6]': ['middle_lane_relay', set(), -1],
#  '[(58.0, 1), (97.0, 1), 1.6]': ['dont_relay', set(), -1],
#  '[(58.0, 1), (110.0, 2), 1.6]': ['dont_relay', set(), -1],
#  '[(58.0, 1), (123.0, 3), 1.6]': ['middle_lane_relay', set(), -1],
#  '[(58.0, 1), (136.0, 1), 1.6]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(58.0, 1), (149.0, 2), 1.6]': ['dont_relay', set(), -1],
#  '[(58.0, 1), (162.0, 3), 1.6]': ['middle_lane_relay', set(), -1],
#  '[(61.00000000000001, 1), (74.5, 2), 1.7000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(61.00000000000001, 1), (88.0, 3), 1.7000000000000002]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(61.00000000000001, 1), (101.50000000000001, 1), 1.7000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(61.00000000000001, 1), (115.00000000000001, 2), 1.7000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(61.00000000000001, 1), (128.5, 3), 1.7000000000000002]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(61.00000000000001, 1), (142.0, 1), 1.7000000000000002]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(61.00000000000001, 1), (155.5, 2), 1.7000000000000002]': ['dont_relay',
#   set(),
#   -1],
#  '[(61.00000000000001, 1), (169.0, 3), 1.7000000000000002]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(64.0, 1), (78.0, 2), 1.8]': ['dont_relay', set(), -1],
#  '[(64.0, 1), (92.0, 3), 1.8]': ['middle_lane_relay', set(), -1],
#  '[(64.0, 1), (106.0, 1), 1.8]': ['dont_relay', set(), -1],
#  '[(64.0, 1), (120.0, 2), 1.8]': ['dont_relay', set(), -1],
#  '[(64.0, 1), (134.0, 3), 1.8]': ['middle_lane_relay', set(), -1],
#  '[(64.0, 1), (148.0, 1), 1.8]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(64.0, 1), (162.0, 2), 1.8]': ['dont_relay', set(), -1],
#  '[(64.0, 1), (176.0, 3), 1.8]': ['middle_lane_relay', set(), -1],
#  '[(67.0, 1), (81.5, 2), 1.9000000000000001]': ['dont_relay', set(), -1],
#  '[(67.0, 1), (96.0, 3), 1.9000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(67.0, 1), (110.5, 1), 1.9000000000000001]': ['dont_relay', set(), -1],
#  '[(67.0, 1), (125.0, 2), 1.9000000000000001]': ['dont_relay', set(), -1],
#  '[(67.0, 1), (139.5, 3), 1.9000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(67.0, 1), (154.0, 1), 1.9000000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(67.0, 1), (168.5, 2), 1.9000000000000001]': ['dont_relay', set(), -1],
#  '[(67.0, 1), (183.0, 3), 1.9000000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(70.0, 1), (85.0, 2), 2.0]': ['dont_relay', set(), -1],
#  '[(70.0, 1), (100.0, 3), 2.0]': ['middle_lane_relay', set(), -1],
#  '[(70.0, 1), (115.0, 1), 2.0]': ['dont_relay', set(), -1],
#  '[(70.0, 1), (130.0, 2), 2.0]': ['dont_relay', set(), -1],
#  '[(70.0, 1), (145.0, 3), 2.0]': ['middle_lane_relay', set(), -1],
#  '[(70.0, 1), (160.0, 1), 2.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(70.0, 1), (175.0, 2), 2.0]': ['dont_relay', set(), -1],
#  '[(70.0, 1), (190.0, 3), 2.0]': ['middle_lane_relay', set(), -1],
#  '[(73.0, 1), (88.5, 2), 2.1]': ['dont_relay', set(), -1],
#  '[(73.0, 1), (104.0, 3), 2.1]': ['middle_lane_relay', set(), -1],
#  '[(73.0, 1), (119.5, 1), 2.1]': ['dont_relay', set(), -1],
#  '[(73.0, 1), (135.0, 2), 2.1]': ['dont_relay', set(), -1],
#  '[(73.0, 1), (150.5, 3), 2.1]': ['middle_lane_relay', set(), -1],
#  '[(73.0, 1), (166.0, 1), 2.1]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(73.0, 1), (181.5, 2), 2.1]': ['dont_relay', set(), -1],
#  '[(73.0, 1), (197.0, 3), 2.1]': ['middle_lane_relay', set(), -1],
#  '[(76.0, 1), (92.0, 2), 2.2]': ['dont_relay', set(), -1],
#  '[(76.0, 1), (108.0, 3), 2.2]': ['middle_lane_relay', set(), -1],
#  '[(76.0, 1), (124.00000000000001, 1), 2.2]': ['dont_relay', set(), -1],
#  '[(76.0, 1), (140.0, 2), 2.2]': ['dont_relay', set(), -1],
#  '[(76.0, 1), (156.0, 3), 2.2]': ['middle_lane_relay', set(), -1],
#  '[(76.0, 1), (172.0, 1), 2.2]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(76.0, 1), (188.0, 2), 2.2]': ['dont_relay', set(), -1],
#  '[(76.0, 1), (204.0, 3), 2.2]': ['middle_lane_relay', set(), -1],
#  '[(79.00000000000001, 1), (95.50000000000001, 2), 2.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(79.00000000000001, 1), (112.00000000000001, 3), 2.3000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(79.00000000000001, 1), (128.5, 1), 2.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(79.00000000000001, 1), (145.0, 2), 2.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(79.00000000000001, 1), (161.5, 3), 2.3000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(79.00000000000001, 1), (178.00000000000003, 1), 2.3000000000000003]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(79.00000000000001, 1), (194.50000000000003, 2), 2.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(79.00000000000001, 1), (211.00000000000003, 3), 2.3000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (99.00000000000001, 2), 2.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (116.00000000000001, 3), 2.4000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (133.0, 1), 2.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (150.0, 2), 2.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (167.00000000000003, 3), 2.4000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (184.00000000000003, 1), 2.4000000000000004]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(82.00000000000001, 1), (201.00000000000003, 2), 2.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(82.00000000000001, 1), (218.00000000000003, 3), 2.4000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(85.0, 1), (102.5, 2), 2.5]': ['dont_relay', set(), -1],
#  '[(85.0, 1), (120.0, 3), 2.5]': ['middle_lane_relay', set(), -1],
#  '[(85.0, 1), (137.5, 1), 2.5]': ['dont_relay', set(), -1],
#  '[(85.0, 1), (155.0, 2), 2.5]': ['dont_relay', set(), -1],
#  '[(85.0, 1), (172.5, 3), 2.5]': ['middle_lane_relay', set(), -1],
#  '[(85.0, 1), (190.0, 1), 2.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(85.0, 1), (207.5, 2), 2.5]': ['dont_relay', set(), -1],
#  '[(85.0, 1), (225.0, 3), 2.5]': ['middle_lane_relay', set(), -1],
#  '[(88.0, 1), (106.0, 2), 2.6]': ['dont_relay', set(), -1],
#  '[(88.0, 1), (124.0, 3), 2.6]': ['middle_lane_relay', set(), -1],
#  '[(88.0, 1), (142.0, 1), 2.6]': ['dont_relay', set(), -1],
#  '[(88.0, 1), (160.0, 2), 2.6]': ['dont_relay', set(), -1],
#  '[(88.0, 1), (178.0, 3), 2.6]': ['middle_lane_relay', set(), -1],
#  '[(88.0, 1), (196.0, 1), 2.6]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(88.0, 1), (214.0, 2), 2.6]': ['dont_relay', set(), -1],
#  '[(88.0, 1), (232.0, 3), 2.6]': ['middle_lane_relay', set(), -1],
#  '[(91.0, 1), (109.5, 2), 2.7]': ['dont_relay', set(), -1],
#  '[(91.0, 1), (128.0, 3), 2.7]': ['middle_lane_relay', set(), -1],
#  '[(91.0, 1), (146.5, 1), 2.7]': ['dont_relay', set(), -1],
#  '[(91.0, 1), (165.0, 2), 2.7]': ['dont_relay', set(), -1],
#  '[(91.0, 1), (183.5, 3), 2.7]': ['middle_lane_relay', set(), -1],
#  '[(91.0, 1), (202.0, 1), 2.7]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(91.0, 1), (220.5, 2), 2.7]': ['dont_relay', set(), -1],
#  '[(91.0, 1), (239.0, 3), 2.7]': ['middle_lane_relay', set(), -1],
#  '[(94.00000000000001, 1), (113.00000000000001, 2), 2.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(94.00000000000001, 1), (132.0, 3), 2.8000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(94.00000000000001, 1), (151.0, 1), 2.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(94.00000000000001, 1), (170.0, 2), 2.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(94.00000000000001, 1), (189.00000000000003, 3), 2.8000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(94.00000000000001, 1), (208.00000000000003, 1), 2.8000000000000003]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(94.00000000000001, 1), (227.00000000000003, 2), 2.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(94.00000000000001, 1), (246.00000000000003, 3), 2.8000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (116.50000000000001, 2), 2.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (136.0, 3), 2.9000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (155.50000000000003, 1), 2.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (175.00000000000003, 2), 2.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (194.50000000000003, 3), 2.9000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (214.00000000000003, 1), 2.9000000000000004]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(97.00000000000001, 1), (233.50000000000003, 2), 2.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(97.00000000000001, 1), (253.00000000000003, 3), 2.9000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(100.0, 1), (120.0, 2), 3.0]': ['dont_relay', set(), -1],
#  '[(100.0, 1), (140.0, 3), 3.0]': ['middle_lane_relay', set(), -1],
#  '[(100.0, 1), (160.0, 1), 3.0]': ['dont_relay', set(), -1],
#  '[(100.0, 1), (180.0, 2), 3.0]': ['dont_relay', set(), -1],
#  '[(100.0, 1), (200.0, 3), 3.0]': ['middle_lane_relay', set(), -1],
#  '[(100.0, 1), (220.0, 1), 3.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(100.0, 1), (240.0, 2), 3.0]': ['dont_relay', set(), -1],
#  '[(100.0, 1), (260.0, 3), 3.0]': ['middle_lane_relay', set(), -1],
#  '[(103.0, 1), (123.5, 2), 3.1]': ['dont_relay', set(), -1],
#  '[(103.0, 1), (144.0, 3), 3.1]': ['middle_lane_relay', set(), -1],
#  '[(103.0, 1), (164.5, 1), 3.1]': ['dont_relay', set(), -1],
#  '[(103.0, 1), (185.0, 2), 3.1]': ['dont_relay', set(), -1],
#  '[(103.0, 1), (205.5, 3), 3.1]': ['middle_lane_relay', set(), -1],
#  '[(103.0, 1), (226.0, 1), 3.1]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(103.0, 1), (246.5, 2), 3.1]': ['dont_relay', set(), -1],
#  '[(103.0, 1), (267.0, 3), 3.1]': ['middle_lane_relay', set(), -1],
#  '[(106.0, 1), (127.0, 2), 3.2]': ['dont_relay', set(), -1],
#  '[(106.0, 1), (148.0, 3), 3.2]': ['middle_lane_relay', set(), -1],
#  '[(106.0, 1), (169.0, 1), 3.2]': ['dont_relay', set(), -1],
#  '[(106.0, 1), (190.0, 2), 3.2]': ['dont_relay', set(), -1],
#  '[(106.0, 1), (211.0, 3), 3.2]': ['middle_lane_relay', set(), -1],
#  '[(106.0, 1), (232.0, 1), 3.2]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(106.0, 1), (253.0, 2), 3.2]': ['dont_relay', set(), -1],
#  '[(106.0, 1), (274.0, 3), 3.2]': ['middle_lane_relay', set(), -1],
#  '[(109.00000000000001, 1), (130.5, 2), 3.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(109.00000000000001, 1), (152.0, 3), 3.3000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(109.00000000000001, 1), (173.5, 1), 3.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(109.00000000000001, 1), (195.0, 2), 3.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(109.00000000000001, 1), (216.50000000000003, 3), 3.3000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(109.00000000000001, 1), (238.00000000000003, 1), 3.3000000000000003]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(109.00000000000001, 1), (259.5, 2), 3.3000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(109.00000000000001, 1), (281.0, 3), 3.3000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (134.0, 2), 3.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (156.0, 3), 3.4000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (178.00000000000003, 1), 3.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (200.00000000000003, 2), 3.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (222.00000000000003, 3), 3.4000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (244.00000000000003, 1), 3.4000000000000004]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(112.00000000000001, 1), (266.0, 2), 3.4000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(112.00000000000001, 1), (288.0, 3), 3.4000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(115.0, 1), (137.5, 2), 3.5]': ['dont_relay', set(), -1],
#  '[(115.0, 1), (160.0, 3), 3.5]': ['middle_lane_relay', set(), -1],
#  '[(115.0, 1), (182.5, 1), 3.5]': ['dont_relay', set(), -1],
#  '[(115.0, 1), (205.0, 2), 3.5]': ['dont_relay', set(), -1],
#  '[(115.0, 1), (227.5, 3), 3.5]': ['middle_lane_relay', set(), -1],
#  '[(115.0, 1), (250.0, 1), 3.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(115.0, 1), (272.5, 2), 3.5]': ['dont_relay', set(), -1],
#  '[(115.0, 1), (295.0, 3), 3.5]': ['middle_lane_relay', set(), -1],
#  '[(118.0, 1), (141.0, 2), 3.6]': ['dont_relay', set(), -1],
#  '[(118.0, 1), (164.0, 3), 3.6]': ['middle_lane_relay', set(), -1],
#  '[(118.0, 1), (187.0, 1), 3.6]': ['dont_relay', set(), -1],
#  '[(118.0, 1), (210.0, 2), 3.6]': ['dont_relay', set(), -1],
#  '[(118.0, 1), (233.0, 3), 3.6]': ['middle_lane_relay', set(), -1],
#  '[(118.0, 1), (256.0, 1), 3.6]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(118.0, 1), (279.0, 2), 3.6]': ['dont_relay', set(), -1],
#  '[(118.0, 1), (302.0, 3), 3.6]': ['middle_lane_relay', set(), -1],
#  '[(121.0, 1), (144.5, 2), 3.7]': ['dont_relay', set(), -1],
#  '[(121.0, 1), (168.0, 3), 3.7]': ['middle_lane_relay', set(), -1],
#  '[(121.0, 1), (191.5, 1), 3.7]': ['dont_relay', set(), -1],
#  '[(121.0, 1), (215.0, 2), 3.7]': ['dont_relay', set(), -1],
#  '[(121.0, 1), (238.5, 3), 3.7]': ['middle_lane_relay', set(), -1],
#  '[(121.0, 1), (262.0, 1), 3.7]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(121.0, 1), (285.5, 2), 3.7]': ['dont_relay', set(), -1],
#  '[(121.0, 1), (309.0, 3), 3.7]': ['middle_lane_relay', set(), -1],
#  '[(124.00000000000001, 1), (148.0, 2), 3.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(124.00000000000001, 1), (172.0, 3), 3.8000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(124.00000000000001, 1), (196.0, 1), 3.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(124.00000000000001, 1), (220.0, 2), 3.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(124.00000000000001, 1), (244.00000000000003, 3), 3.8000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(124.00000000000001, 1), (268.0, 1), 3.8000000000000003]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(124.00000000000001, 1), (292.0, 2), 3.8000000000000003]': ['dont_relay',
#   set(),
#   -1],
#  '[(124.00000000000001, 1), (316.0, 3), 3.8000000000000003]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (151.5, 2), 3.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (176.0, 3), 3.9000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (200.50000000000003, 1), 3.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (225.00000000000003, 2), 3.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (249.50000000000003, 3), 3.9000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (274.0, 1), 3.9000000000000004]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(127.00000000000001, 1), (298.5, 2), 3.9000000000000004]': ['dont_relay',
#   set(),
#   -1],
#  '[(127.00000000000001, 1), (323.0, 3), 3.9000000000000004]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(130.0, 1), (155.0, 2), 4.0]': ['dont_relay', set(), -1],
#  '[(130.0, 1), (180.0, 3), 4.0]': ['middle_lane_relay', set(), -1],
#  '[(130.0, 1), (205.0, 1), 4.0]': ['dont_relay', set(), -1],
#  '[(130.0, 1), (230.0, 2), 4.0]': ['dont_relay', set(), -1],
#  '[(130.0, 1), (255.0, 3), 4.0]': ['middle_lane_relay', set(), -1],
#  '[(130.0, 1), (280.0, 1), 4.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(130.0, 1), (305.0, 2), 4.0]': ['dont_relay', set(), -1],
#  '[(130.0, 1), (330.0, 3), 4.0]': ['middle_lane_relay', set(), -1],
#  '[(133.0, 1), (158.50000000000003, 2), 4.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(133.0, 1), (184.00000000000003, 3), 4.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(133.0, 1), (209.50000000000003, 1), 4.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(133.0, 1), (235.00000000000003, 2), 4.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(133.0, 1), (260.5, 3), 4.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(133.0, 1), (286.0, 1), 4.1000000000000005]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(133.0, 1), (311.50000000000006, 2), 4.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(133.0, 1), (337.00000000000006, 3), 4.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(136.0, 1), (162.0, 2), 4.2]': ['dont_relay', set(), -1],
#  '[(136.0, 1), (188.0, 3), 4.2]': ['middle_lane_relay', set(), -1],
#  '[(136.0, 1), (214.0, 1), 4.2]': ['dont_relay', set(), -1],
#  '[(136.0, 1), (240.0, 2), 4.2]': ['dont_relay', set(), -1],
#  '[(136.0, 1), (266.0, 3), 4.2]': ['middle_lane_relay', set(), -1],
#  '[(136.0, 1), (292.0, 1), 4.2]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(136.0, 1), (318.0, 2), 4.2]': ['dont_relay', set(), -1],
#  '[(136.0, 1), (344.0, 3), 4.2]': ['middle_lane_relay', set(), -1],
#  '[(139.0, 1), (165.5, 2), 4.3]': ['dont_relay', set(), -1],
#  '[(139.0, 1), (192.0, 3), 4.3]': ['middle_lane_relay', set(), -1],
#  '[(139.0, 1), (218.5, 1), 4.3]': ['dont_relay', set(), -1],
#  '[(139.0, 1), (245.0, 2), 4.3]': ['dont_relay', set(), -1],
#  '[(139.0, 1), (271.5, 3), 4.3]': ['middle_lane_relay', set(), -1],
#  '[(139.0, 1), (298.0, 1), 4.3]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(139.0, 1), (324.5, 2), 4.3]': ['dont_relay', set(), -1],
#  '[(139.0, 1), (351.0, 3), 4.3]': ['middle_lane_relay', set(), -1],
#  '[(142.0, 1), (169.0, 2), 4.4]': ['dont_relay', set(), -1],
#  '[(142.0, 1), (196.0, 3), 4.4]': ['middle_lane_relay', set(), -1],
#  '[(142.0, 1), (223.00000000000003, 1), 4.4]': ['dont_relay', set(), -1],
#  '[(142.0, 1), (250.00000000000003, 2), 4.4]': ['dont_relay', set(), -1],
#  '[(142.0, 1), (277.0, 3), 4.4]': ['middle_lane_relay', set(), -1],
#  '[(142.0, 1), (304.0, 1), 4.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(142.0, 1), (331.0, 2), 4.4]': ['dont_relay', set(), -1],
#  '[(142.0, 1), (358.0, 3), 4.4]': ['middle_lane_relay', set(), -1],
#  '[(145.0, 1), (172.5, 2), 4.5]': ['dont_relay', set(), -1],
#  '[(145.0, 1), (200.0, 3), 4.5]': ['middle_lane_relay', set(), -1],
#  '[(145.0, 1), (227.5, 1), 4.5]': ['dont_relay', set(), -1],
#  '[(145.0, 1), (255.0, 2), 4.5]': ['dont_relay', set(), -1],
#  '[(145.0, 1), (282.5, 3), 4.5]': ['middle_lane_relay', set(), -1],
#  '[(145.0, 1), (310.0, 1), 4.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(145.0, 1), (337.5, 2), 4.5]': ['dont_relay', set(), -1],
#  '[(145.0, 1), (365.0, 3), 4.5]': ['middle_lane_relay', set(), -1],
#  '[(148.00000000000003, 1), (176.00000000000003, 2), 4.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(148.00000000000003, 1), (204.00000000000003, 3), 4.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(148.00000000000003, 1), (232.00000000000003, 1), 4.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(148.00000000000003, 1), (260.0, 2), 4.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(148.00000000000003, 1), (288.0, 3), 4.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(148.00000000000003, 1), (316.00000000000006, 1), 4.6000000000000005]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(148.00000000000003, 1), (344.00000000000006, 2), 4.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(148.00000000000003, 1), (372.00000000000006, 3), 4.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(151.0, 1), (179.5, 2), 4.7]': ['dont_relay', set(), -1],
#  '[(151.0, 1), (208.0, 3), 4.7]': ['middle_lane_relay', set(), -1],
#  '[(151.0, 1), (236.5, 1), 4.7]': ['dont_relay', set(), -1],
#  '[(151.0, 1), (265.0, 2), 4.7]': ['dont_relay', set(), -1],
#  '[(151.0, 1), (293.5, 3), 4.7]': ['middle_lane_relay', set(), -1],
#  '[(151.0, 1), (322.0, 1), 4.7]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(151.0, 1), (350.5, 2), 4.7]': ['dont_relay', set(), -1],
#  '[(151.0, 1), (379.0, 3), 4.7]': ['middle_lane_relay', set(), -1],
#  '[(154.00000000000003, 1), (183.00000000000003, 2), 4.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(154.00000000000003, 1), (212.00000000000003, 3), 4.800000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(154.00000000000003, 1), (241.00000000000003, 1), 4.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(154.00000000000003, 1), (270.0, 2), 4.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(154.00000000000003, 1), (299.00000000000006, 3), 4.800000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(154.00000000000003, 1), (328.00000000000006, 1), 4.800000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(154.00000000000003, 1), (357.00000000000006, 2), 4.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(154.00000000000003, 1), (386.00000000000006, 3), 4.800000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(157.0, 1), (186.5, 2), 4.9]': ['dont_relay', set(), -1],
#  '[(157.0, 1), (216.0, 3), 4.9]': ['middle_lane_relay', set(), -1],
#  '[(157.0, 1), (245.50000000000003, 1), 4.9]': ['dont_relay', set(), -1],
#  '[(157.0, 1), (275.0, 2), 4.9]': ['dont_relay', set(), -1],
#  '[(157.0, 1), (304.5, 3), 4.9]': ['middle_lane_relay', set(), -1],
#  '[(157.0, 1), (334.0, 1), 4.9]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(157.0, 1), (363.5, 2), 4.9]': ['dont_relay', set(), -1],
#  '[(157.0, 1), (393.0, 3), 4.9]': ['middle_lane_relay', set(), -1],
#  '[(160.0, 1), (190.0, 2), 5.0]': ['dont_relay', set(), -1],
#  '[(160.0, 1), (220.0, 3), 5.0]': ['middle_lane_relay', set(), -1],
#  '[(160.0, 1), (250.0, 1), 5.0]': ['dont_relay', set(), -1],
#  '[(160.0, 1), (280.0, 2), 5.0]': ['dont_relay', set(), -1],
#  '[(160.0, 1), (310.0, 3), 5.0]': ['middle_lane_relay', set(), -1],
#  '[(160.0, 1), (340.0, 1), 5.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(160.0, 1), (370.0, 2), 5.0]': ['dont_relay', set(), -1],
#  '[(160.0, 1), (400.0, 3), 5.0]': ['middle_lane_relay', set(), -1],
#  '[(163.00000000000003, 1), (193.50000000000003, 2), 5.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(163.00000000000003, 1), (224.00000000000003, 3), 5.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(163.00000000000003, 1), (254.50000000000003, 1), 5.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(163.00000000000003, 1), (285.0, 2), 5.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(163.00000000000003, 1), (315.50000000000006, 3), 5.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(163.00000000000003, 1), (346.00000000000006, 1), 5.1000000000000005]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(163.00000000000003, 1), (376.50000000000006, 2), 5.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(163.00000000000003, 1), (407.00000000000006, 3), 5.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(166.0, 1), (197.0, 2), 5.2]': ['dont_relay', set(), -1],
#  '[(166.0, 1), (228.0, 3), 5.2]': ['middle_lane_relay', set(), -1],
#  '[(166.0, 1), (259.0, 1), 5.2]': ['dont_relay', set(), -1],
#  '[(166.0, 1), (290.0, 2), 5.2]': ['dont_relay', set(), -1],
#  '[(166.0, 1), (321.0, 3), 5.2]': ['middle_lane_relay', set(), -1],
#  '[(166.0, 1), (352.0, 1), 5.2]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(166.0, 1), (383.0, 2), 5.2]': ['dont_relay', set(), -1],
#  '[(166.0, 1), (414.0, 3), 5.2]': ['middle_lane_relay', set(), -1],
#  '[(169.00000000000003, 1), (200.50000000000003, 2), 5.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(169.00000000000003, 1), (232.00000000000003, 3), 5.300000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(169.00000000000003, 1), (263.5, 1), 5.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(169.00000000000003, 1), (295.00000000000006, 2), 5.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(169.00000000000003, 1), (326.50000000000006, 3), 5.300000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(169.00000000000003, 1), (358.00000000000006, 1), 5.300000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(169.00000000000003, 1), (389.50000000000006, 2), 5.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(169.00000000000003, 1), (421.00000000000006, 3), 5.300000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(172.0, 1), (204.0, 2), 5.4]': ['dont_relay', set(), -1],
#  '[(172.0, 1), (236.0, 3), 5.4]': ['middle_lane_relay', set(), -1],
#  '[(172.0, 1), (268.0, 1), 5.4]': ['dont_relay', set(), -1],
#  '[(172.0, 1), (300.0, 2), 5.4]': ['dont_relay', set(), -1],
#  '[(172.0, 1), (332.0, 3), 5.4]': ['middle_lane_relay', set(), -1],
#  '[(172.0, 1), (364.0, 1), 5.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(172.0, 1), (396.0, 2), 5.4]': ['dont_relay', set(), -1],
#  '[(172.0, 1), (428.0, 3), 5.4]': ['middle_lane_relay', set(), -1],
#  '[(175.0, 1), (207.5, 2), 5.5]': ['dont_relay', set(), -1],
#  '[(175.0, 1), (240.0, 3), 5.5]': ['middle_lane_relay', set(), -1],
#  '[(175.0, 1), (272.5, 1), 5.5]': ['dont_relay', set(), -1],
#  '[(175.0, 1), (305.0, 2), 5.5]': ['dont_relay', set(), -1],
#  '[(175.0, 1), (337.5, 3), 5.5]': ['middle_lane_relay', set(), -1],
#  '[(175.0, 1), (370.0, 1), 5.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(175.0, 1), (402.5, 2), 5.5]': ['dont_relay', set(), -1],
#  '[(175.0, 1), (435.0, 3), 5.5]': ['middle_lane_relay', set(), -1],
#  '[(178.00000000000003, 1), (211.00000000000003, 2), 5.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(178.00000000000003, 1), (244.00000000000003, 3), 5.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(178.00000000000003, 1), (277.0, 1), 5.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(178.00000000000003, 1), (310.0, 2), 5.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(178.00000000000003, 1), (343.00000000000006, 3), 5.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(178.00000000000003, 1), (376.00000000000006, 1), 5.6000000000000005]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(178.00000000000003, 1), (409.00000000000006, 2), 5.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(178.00000000000003, 1), (442.00000000000006, 3), 5.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(181.0, 1), (214.5, 2), 5.7]': ['dont_relay', set(), -1],
#  '[(181.0, 1), (248.0, 3), 5.7]': ['middle_lane_relay', set(), -1],
#  '[(181.0, 1), (281.5, 1), 5.7]': ['dont_relay', set(), -1],
#  '[(181.0, 1), (315.0, 2), 5.7]': ['dont_relay', set(), -1],
#  '[(181.0, 1), (348.5, 3), 5.7]': ['middle_lane_relay', set(), -1],
#  '[(181.0, 1), (382.0, 1), 5.7]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(181.0, 1), (415.5, 2), 5.7]': ['dont_relay', set(), -1],
#  '[(181.0, 1), (449.0, 3), 5.7]': ['middle_lane_relay', set(), -1],
#  '[(184.00000000000003, 1), (218.00000000000003, 2), 5.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(184.00000000000003, 1), (252.00000000000003, 3), 5.800000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(184.00000000000003, 1), (286.00000000000006, 1), 5.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(184.00000000000003, 1), (320.00000000000006, 2), 5.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(184.00000000000003, 1), (354.00000000000006, 3), 5.800000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(184.00000000000003, 1), (388.00000000000006, 1), 5.800000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(184.00000000000003, 1), (422.00000000000006, 2), 5.800000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(184.00000000000003, 1), (456.00000000000006, 3), 5.800000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(187.0, 1), (221.5, 2), 5.9]': ['dont_relay', set(), -1],
#  '[(187.0, 1), (256.0, 3), 5.9]': ['middle_lane_relay', set(), -1],
#  '[(187.0, 1), (290.5, 1), 5.9]': ['dont_relay', set(), -1],
#  '[(187.0, 1), (325.0, 2), 5.9]': ['dont_relay', set(), -1],
#  '[(187.0, 1), (359.5, 3), 5.9]': ['middle_lane_relay', set(), -1],
#  '[(187.0, 1), (394.0, 1), 5.9]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(187.0, 1), (428.5, 2), 5.9]': ['dont_relay', set(), -1],
#  '[(187.0, 1), (463.0, 3), 5.9]': ['middle_lane_relay', set(), -1],
#  '[(190.0, 1), (225.0, 2), 6.0]': ['dont_relay', set(), -1],
#  '[(190.0, 1), (260.0, 3), 6.0]': ['middle_lane_relay', set(), -1],
#  '[(190.0, 1), (295.0, 1), 6.0]': ['dont_relay', set(), -1],
#  '[(190.0, 1), (330.0, 2), 6.0]': ['dont_relay', set(), -1],
#  '[(190.0, 1), (365.0, 3), 6.0]': ['middle_lane_relay', set(), -1],
#  '[(190.0, 1), (400.0, 1), 6.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(190.0, 1), (435.0, 2), 6.0]': ['dont_relay', set(), -1],
#  '[(190.0, 1), (470.0, 3), 6.0]': ['middle_lane_relay', set(), -1],
#  '[(193.00000000000003, 1), (228.50000000000003, 2), 6.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(193.00000000000003, 1), (264.0, 3), 6.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(193.00000000000003, 1), (299.5, 1), 6.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(193.00000000000003, 1), (335.0, 2), 6.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(193.00000000000003, 1), (370.50000000000006, 3), 6.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(193.00000000000003, 1), (406.00000000000006, 1), 6.1000000000000005]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(193.00000000000003, 1), (441.50000000000006, 2), 6.1000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(193.00000000000003, 1), (477.00000000000006, 3), 6.1000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(196.0, 1), (232.0, 2), 6.2]': ['dont_relay', set(), -1],
#  '[(196.0, 1), (268.0, 3), 6.2]': ['middle_lane_relay', set(), -1],
#  '[(196.0, 1), (304.0, 1), 6.2]': ['dont_relay', set(), -1],
#  '[(196.0, 1), (340.0, 2), 6.2]': ['dont_relay', set(), -1],
#  '[(196.0, 1), (376.0, 3), 6.2]': ['middle_lane_relay', set(), -1],
#  '[(196.0, 1), (412.0, 1), 6.2]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(196.0, 1), (448.0, 2), 6.2]': ['dont_relay', set(), -1],
#  '[(196.0, 1), (484.0, 3), 6.2]': ['middle_lane_relay', set(), -1],
#  '[(199.00000000000003, 1), (235.50000000000003, 2), 6.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(199.00000000000003, 1), (272.0, 3), 6.300000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(199.00000000000003, 1), (308.50000000000006, 1), 6.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(199.00000000000003, 1), (345.00000000000006, 2), 6.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(199.00000000000003, 1), (381.50000000000006, 3), 6.300000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(199.00000000000003, 1), (418.00000000000006, 1), 6.300000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(199.00000000000003, 1), (454.50000000000006, 2), 6.300000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(199.00000000000003, 1), (491.00000000000006, 3), 6.300000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(202.0, 1), (239.0, 2), 6.4]': ['dont_relay', set(), -1],
#  '[(202.0, 1), (276.0, 3), 6.4]': ['middle_lane_relay', set(), -1],
#  '[(202.0, 1), (313.0, 1), 6.4]': ['dont_relay', set(), -1],
#  '[(202.0, 1), (350.0, 2), 6.4]': ['dont_relay', set(), -1],
#  '[(202.0, 1), (387.0, 3), 6.4]': ['middle_lane_relay', set(), -1],
#  '[(202.0, 1), (424.0, 1), 6.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(202.0, 1), (461.0, 2), 6.4]': ['dont_relay', set(), -1],
#  '[(202.0, 1), (498.0, 3), 6.4]': ['middle_lane_relay', set(), -1],
#  '[(205.0, 1), (242.5, 2), 6.5]': ['dont_relay', set(), -1],
#  '[(205.0, 1), (280.0, 3), 6.5]': ['middle_lane_relay', set(), -1],
#  '[(205.0, 1), (317.5, 1), 6.5]': ['dont_relay', set(), -1],
#  '[(205.0, 1), (355.0, 2), 6.5]': ['dont_relay', set(), -1],
#  '[(205.0, 1), (392.5, 3), 6.5]': ['middle_lane_relay', set(), -1],
#  '[(205.0, 1), (430.0, 1), 6.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(205.0, 1), (467.5, 2), 6.5]': ['dont_relay', set(), -1],
#  '[(205.0, 1), (505.0, 3), 6.5]': ['middle_lane_relay', set(), -1],
#  '[(208.00000000000003, 1), (246.00000000000003, 2), 6.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(208.00000000000003, 1), (284.0, 3), 6.6000000000000005]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(208.00000000000003, 1), (322.0, 1), 6.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
#  '[(208.00000000000003, 1), (360.0, 2), 6.6000000000000005]': ['dont_relay',
#   set(),
#   -1],
# ...
#  '[(319.0, 1), (714.5, 2), 10.3]': ['dont_relay', set(), -1],
#  '[(319.0, 1), (771.0, 3), 10.3]': ['middle_lane_relay', set(), -1],
#  '[(322.0, 1), (379.0, 2), 10.4]': ['dont_relay', set(), -1],
#  '[(322.0, 1), (436.0, 3), 10.4]': ['middle_lane_relay', set(), -1],
#  '[(322.0, 1), (493.0, 1), 10.4]': ['dont_relay', set(), -1],
#  '[(322.0, 1), (550.0, 2), 10.4]': ['dont_relay', set(), -1],
#  '[(322.0, 1), (607.0, 3), 10.4]': ['middle_lane_relay', set(), -1],
#  '[(322.0, 1), (664.0, 1), 10.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(322.0, 1), (721.0, 2), 10.4]': ['dont_relay', set(), -1],
#  '[(322.0, 1), (778.0, 3), 10.4]': ['middle_lane_relay', set(), -1],
#  '[(325.0, 1), (382.5, 2), 10.5]': ['dont_relay', set(), -1],
#  '[(325.0, 1), (440.0, 3), 10.5]': ['middle_lane_relay', set(), -1],
#  '[(325.0, 1), (497.5, 1), 10.5]': ['dont_relay', set(), -1],
#  '[(325.0, 1), (555.0, 2), 10.5]': ['dont_relay', set(), -1],
#  '[(325.0, 1), (612.5, 3), 10.5]': ['middle_lane_relay', set(), -1],
#  '[(325.0, 1), (670.0, 1), 10.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(325.0, 1), (727.5, 2), 10.5]': ['dont_relay', set(), -1],
#  '[(325.0, 1), (785.0, 3), 10.5]': ['middle_lane_relay', set(), -1],
#  '[(328.00000000000006, 1), (386.00000000000006, 2), 10.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(328.00000000000006, 1), (444.00000000000006, 3), 10.600000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(328.00000000000006, 1), (502.00000000000006, 1), 10.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(328.00000000000006, 1), (560.0000000000001, 2), 10.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(328.00000000000006, 1), (618.0000000000001, 3), 10.600000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(328.00000000000006, 1), (676.0000000000001, 1), 10.600000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(328.00000000000006, 1), (734.0000000000001, 2), 10.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(328.00000000000006, 1), (792.0000000000001, 3), 10.600000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (389.50000000000006, 2), 10.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (448.00000000000006, 3), 10.700000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (506.50000000000006, 1), 10.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (565.0, 2), 10.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (623.5000000000001, 3), 10.700000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (682.0000000000001, 1), 10.700000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(331.00000000000006, 1), (740.5000000000001, 2), 10.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(331.00000000000006, 1), (799.0000000000001, 3), 10.700000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(334.0, 1), (393.0, 2), 10.8]': ['dont_relay', set(), -1],
#  '[(334.0, 1), (452.0, 3), 10.8]': ['middle_lane_relay', set(), -1],
#  '[(334.0, 1), (511.00000000000006, 1), 10.8]': ['dont_relay', set(), -1],
#  '[(334.0, 1), (570.0, 2), 10.8]': ['dont_relay', set(), -1],
#  '[(334.0, 1), (629.0, 3), 10.8]': ['middle_lane_relay', set(), -1],
#  '[(334.0, 1), (688.0, 1), 10.8]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(334.0, 1), (747.0, 2), 10.8]': ['dont_relay', set(), -1],
#  '[(334.0, 1), (806.0, 3), 10.8]': ['middle_lane_relay', set(), -1],
#  '[(337.0, 1), (396.5, 2), 10.9]': ['dont_relay', set(), -1],
#  '[(337.0, 1), (456.0, 3), 10.9]': ['middle_lane_relay', set(), -1],
#  '[(337.0, 1), (515.5, 1), 10.9]': ['dont_relay', set(), -1],
#  '[(337.0, 1), (575.0, 2), 10.9]': ['dont_relay', set(), -1],
#  '[(337.0, 1), (634.5, 3), 10.9]': ['middle_lane_relay', set(), -1],
#  '[(337.0, 1), (694.0, 1), 10.9]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(337.0, 1), (753.5, 2), 10.9]': ['dont_relay', set(), -1],
#  '[(337.0, 1), (813.0, 3), 10.9]': ['middle_lane_relay', set(), -1],
#  '[(340.0, 1), (400.0, 2), 11.0]': ['dont_relay', set(), -1],
#  '[(340.0, 1), (460.0, 3), 11.0]': ['middle_lane_relay', set(), -1],
#  '[(340.0, 1), (520.0, 1), 11.0]': ['dont_relay', set(), -1],
#  '[(340.0, 1), (580.0, 2), 11.0]': ['dont_relay', set(), -1],
#  '[(340.0, 1), (640.0, 3), 11.0]': ['middle_lane_relay', set(), -1],
#  '[(340.0, 1), (700.0, 1), 11.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(340.0, 1), (760.0, 2), 11.0]': ['dont_relay', set(), -1],
#  '[(340.0, 1), (820.0, 3), 11.0]': ['middle_lane_relay', set(), -1],
#  '[(343.00000000000006, 1), (403.50000000000006, 2), 11.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(343.00000000000006, 1), (464.00000000000006, 3), 11.100000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(343.00000000000006, 1), (524.5, 1), 11.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(343.00000000000006, 1), (585.0000000000001, 2), 11.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(343.00000000000006, 1), (645.5000000000001, 3), 11.100000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(343.00000000000006, 1), (706.0000000000001, 1), 11.100000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(343.00000000000006, 1), (766.5000000000001, 2), 11.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(343.00000000000006, 1), (827.0000000000001, 3), 11.100000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (407.00000000000006, 2), 11.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (468.00000000000006, 3), 11.200000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (529.0, 1), 11.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (590.0, 2), 11.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (651.0000000000001, 3), 11.200000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (712.0000000000001, 1), 11.200000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(346.00000000000006, 1), (773.0000000000001, 2), 11.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(346.00000000000006, 1), (834.0000000000001, 3), 11.200000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(349.0, 1), (410.5, 2), 11.3]': ['dont_relay', set(), -1],
#  '[(349.0, 1), (472.0, 3), 11.3]': ['middle_lane_relay', set(), -1],
#  '[(349.0, 1), (533.5, 1), 11.3]': ['dont_relay', set(), -1],
#  '[(349.0, 1), (595.0, 2), 11.3]': ['dont_relay', set(), -1],
#  '[(349.0, 1), (656.5, 3), 11.3]': ['middle_lane_relay', set(), -1],
#  '[(349.0, 1), (718.0, 1), 11.3]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(349.0, 1), (779.5, 2), 11.3]': ['dont_relay', set(), -1],
#  '[(349.0, 1), (841.0, 3), 11.3]': ['middle_lane_relay', set(), -1],
#  '[(352.0, 1), (414.0, 2), 11.4]': ['dont_relay', set(), -1],
#  '[(352.0, 1), (476.0, 3), 11.4]': ['middle_lane_relay', set(), -1],
#  '[(352.0, 1), (538.0, 1), 11.4]': ['dont_relay', set(), -1],
#  '[(352.0, 1), (600.0, 2), 11.4]': ['dont_relay', set(), -1],
#  '[(352.0, 1), (662.0, 3), 11.4]': ['middle_lane_relay', set(), -1],
#  '[(352.0, 1), (724.0, 1), 11.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(352.0, 1), (786.0, 2), 11.4]': ['dont_relay', set(), -1],
#  '[(352.0, 1), (848.0, 3), 11.4]': ['middle_lane_relay', set(), -1],
#  '[(355.0, 1), (417.5, 2), 11.5]': ['dont_relay', set(), -1],
#  '[(355.0, 1), (480.0, 3), 11.5]': ['middle_lane_relay', set(), -1],
#  '[(355.0, 1), (542.5, 1), 11.5]': ['dont_relay', set(), -1],
#  '[(355.0, 1), (605.0, 2), 11.5]': ['dont_relay', set(), -1],
#  '[(355.0, 1), (667.5, 3), 11.5]': ['middle_lane_relay', set(), -1],
#  '[(355.0, 1), (730.0, 1), 11.5]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(355.0, 1), (792.5, 2), 11.5]': ['dont_relay', set(), -1],
#  '[(355.0, 1), (855.0, 3), 11.5]': ['middle_lane_relay', set(), -1],
#  '[(358.00000000000006, 1), (421.00000000000006, 2), 11.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(358.00000000000006, 1), (484.00000000000006, 3), 11.600000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(358.00000000000006, 1), (547.0000000000001, 1), 11.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(358.00000000000006, 1), (610.0000000000001, 2), 11.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(358.00000000000006, 1), (673.0000000000001, 3), 11.600000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(358.00000000000006, 1), (736.0000000000001, 1), 11.600000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(358.00000000000006, 1), (799.0000000000001, 2), 11.600000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(358.00000000000006, 1), (862.0000000000001, 3), 11.600000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (424.50000000000006, 2), 11.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (488.00000000000006, 3), 11.700000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (551.5, 1), 11.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (615.0, 2), 11.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (678.5000000000001, 3), 11.700000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (742.0000000000001, 1), 11.700000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(361.00000000000006, 1), (805.5000000000001, 2), 11.700000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(361.00000000000006, 1), (869.0000000000001, 3), 11.700000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(364.0, 1), (428.0, 2), 11.8]': ['dont_relay', set(), -1],
#  '[(364.0, 1), (492.0, 3), 11.8]': ['middle_lane_relay', set(), -1],
#  '[(364.0, 1), (556.0, 1), 11.8]': ['dont_relay', set(), -1],
#  '[(364.0, 1), (620.0, 2), 11.8]': ['dont_relay', set(), -1],
#  '[(364.0, 1), (684.0, 3), 11.8]': ['middle_lane_relay', set(), -1],
#  '[(364.0, 1), (748.0, 1), 11.8]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(364.0, 1), (812.0, 2), 11.8]': ['dont_relay', set(), -1],
#  '[(364.0, 1), (876.0, 3), 11.8]': ['middle_lane_relay', set(), -1],
#  '[(367.0, 1), (431.5, 2), 11.9]': ['dont_relay', set(), -1],
#  '[(367.0, 1), (496.0, 3), 11.9]': ['middle_lane_relay', set(), -1],
#  '[(367.0, 1), (560.5, 1), 11.9]': ['dont_relay', set(), -1],
#  '[(367.0, 1), (625.0, 2), 11.9]': ['dont_relay', set(), -1],
#  '[(367.0, 1), (689.5, 3), 11.9]': ['middle_lane_relay', set(), -1],
#  '[(367.0, 1), (754.0, 1), 11.9]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(367.0, 1), (818.5, 2), 11.9]': ['dont_relay', set(), -1],
#  '[(367.0, 1), (883.0, 3), 11.9]': ['middle_lane_relay', set(), -1],
#  '[(370.0, 1), (435.0, 2), 12.0]': ['dont_relay', set(), -1],
#  '[(370.0, 1), (500.0, 3), 12.0]': ['middle_lane_relay', set(), -1],
#  '[(370.0, 1), (565.0, 1), 12.0]': ['dont_relay', set(), -1],
#  '[(370.0, 1), (630.0, 2), 12.0]': ['dont_relay', set(), -1],
#  '[(370.0, 1), (695.0, 3), 12.0]': ['middle_lane_relay', set(), -1],
#  '[(370.0, 1), (760.0, 1), 12.0]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(370.0, 1), (825.0, 2), 12.0]': ['dont_relay', set(), -1],
#  '[(370.0, 1), (890.0, 3), 12.0]': ['middle_lane_relay', set(), -1],
#  '[(373.00000000000006, 1), (438.50000000000006, 2), 12.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(373.00000000000006, 1), (504.00000000000006, 3), 12.100000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(373.00000000000006, 1), (569.5000000000001, 1), 12.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(373.00000000000006, 1), (635.0000000000001, 2), 12.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(373.00000000000006, 1), (700.5000000000001, 3), 12.100000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(373.00000000000006, 1), (766.0000000000001, 1), 12.100000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(373.00000000000006, 1), (831.5000000000001, 2), 12.100000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(373.00000000000006, 1), (897.0000000000001, 3), 12.100000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (442.00000000000006, 2), 12.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (508.00000000000006, 3), 12.200000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (574.0, 1), 12.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (640.0, 2), 12.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (706.0000000000001, 3), 12.200000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (772.0000000000001, 1), 12.200000000000001]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(376.00000000000006, 1), (838.0000000000001, 2), 12.200000000000001]': ['dont_relay',
#   set(),
#   -1],
#  '[(376.00000000000006, 1), (904.0000000000001, 3), 12.200000000000001]': ['middle_lane_relay',
#   set(),
#   -1],
#  '[(379.0, 1), (445.5, 2), 12.3]': ['dont_relay', set(), -1],
#  '[(379.0, 1), (512.0, 3), 12.3]': ['middle_lane_relay', set(), -1],
#  '[(379.0, 1), (578.5, 1), 12.3]': ['dont_relay', set(), -1],
#  '[(379.0, 1), (645.0, 2), 12.3]': ['dont_relay', set(), -1],
#  '[(379.0, 1), (711.5, 3), 12.3]': ['middle_lane_relay', set(), -1],
#  '[(379.0, 1), (778.0, 1), 12.3]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(379.0, 1), (844.5, 2), 12.3]': ['dont_relay', set(), -1],
#  '[(379.0, 1), (911.0, 3), 12.3]': ['middle_lane_relay', set(), -1],
#  '[(382.0, 1), (449.0, 2), 12.4]': ['dont_relay', set(), -1],
#  '[(382.0, 1), (516.0, 3), 12.4]': ['middle_lane_relay', set(), -1],
#  '[(382.0, 1), (583.0, 1), 12.4]': ['dont_relay', set(), -1],
#  '[(382.0, 1), (650.0, 2), 12.4]': ['dont_relay', set(), -1],
#  '[(382.0, 1), (717.0, 3), 12.4]': ['middle_lane_relay', set(), -1],
#  '[(382.0, 1), (784.0, 1), 12.4]': ['same_lane_relay',
#   {<ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>},
#   <ipynb.fs.full.Environment.Vehicle at 0x7fb754368710>],
#  '[(382.0, 1), (851.0, 2), 12.4]': ['dont_relay', set(), -1],
#  '[(382.0, 1), (918.0, 3), 12.4]': ['middle_lane_relay', set(), -1],
#  ...}

# %%
Graphs.adjacency_list
# Out:
# {}
